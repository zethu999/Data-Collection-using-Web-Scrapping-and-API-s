# %%
import yfinance as yf
import pandas as pd

# %%
apple_data = yf.Ticker("AAPL")
apple_data
# Out:
# yfinance.Ticker object <AAPL>

# %%
info = apple_data.info
info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 154000,
# ...

# %%
stock_data = apple_data.history(period='max')
stock_data
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 1980-12-12    0.100039    0.100474    0.100039    0.100039  469033600
# 1980-12-15    0.095255    0.095255    0.094820    0.094820  175884800
# 1980-12-16    0.088296    0.088296    0.087861    0.087861  105728000
# 1980-12-17    0.090035    0.090470    0.090035    0.090035   86441600
# 1980-12-18    0.092646    0.093081    0.092646    0.092646   73449600
# ...                ...         ...         ...         ...        ...
# 2022-09-15  154.649994  155.240005  151.380005  152.369995   90481100
# 2022-09-16  151.210007  151.350006  148.369995  150.699997  162157000
# 2022-09-19  149.309998  154.559998  149.100006  154.479996   81474200
# 2022-09-20  153.399994  158.080002  153.080002  156.899994  107547900
# 2022-09-21  157.339996  158.399994  155.919998  157.164993   35043254
#
#             Dividends  Stock Splits
# Date
# 1980-12-12        0.0           0.0
# 1980-12-15        0.0           0.0
# ...

# %%
stock_data.reset_index(inplace=True)

# %%
print(stock_data.to_string())
# Out:
#             Date        Open        High         Low       Close      Volume  Dividends  Stock Splits
# 0     1980-12-12    0.100039    0.100474    0.100039    0.100039   469033600   0.000000           0.0
# 1     1980-12-15    0.095255    0.095255    0.094820    0.094820   175884800   0.000000           0.0
# 2     1980-12-16    0.088296    0.088296    0.087861    0.087861   105728000   0.000000           0.0
# 3     1980-12-17    0.090035    0.090470    0.090035    0.090035    86441600   0.000000           0.0
# 4     1980-12-18    0.092646    0.093081    0.092646    0.092646    73449600   0.000000           0.0
# 5     1980-12-19    0.098300    0.098735    0.098300    0.098300    48630400   0.000000           0.0
# 6     1980-12-22    0.103084    0.103520    0.103084    0.103084    37363200   0.000000           0.0
# 7     1980-12-23    0.107434    0.107869    0.107434    0.107434    46950400   0.000000           0.0
# ...

# %%
stock_data.plot(x="Date",y="Open")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock_data.plot(x="Date",y="Close")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock_data.plot(x="Date",y="High")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock_data.plot(x="Date",y="Low")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock_data.plot(x="Date",y="Volume")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock_data.plot(x="Date",y="Dividends")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock_data.plot(x="Date",y="Stock Splits")
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock_data.dtypes
# Out:
# Date            datetime64[ns]
# Open                   float64
# High                   float64
# Low                    float64
# Close                  float64
# Volume                   int64
# Dividends              float64
# Stock Splits           float64
# dtype: object

# %%
stData_exe = stock_data.astype({'Date':'str'})

# %%
stData_exe.to_excel("appledat.xlsx",sheet_name='Sheet_name_1')

# %%
stData_exe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10533 entries, 0 to 10532
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          10533 non-null  object
#  1   Open          10533 non-null  float64
#  2   High          10533 non-null  float64
#  3   Low           10533 non-null  float64
#  4   Close         10533 non-null  float64
#  5   Volume        10533 non-null  int64
#  6   Dividends     10533 non-null  float64
#  7   Stock Splits  10533 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 658.4+ KB

# %%
stData_exe.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
stData_exe.keys()
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Dividends',
#        'Stock Splits'],
#       dtype='object')

# %%
stData_exe.empty
# Out:
# False
